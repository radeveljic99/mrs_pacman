# %%
import gym
from gym.utils import play
import os
from stable_baselines3 import A2C

models_dir =  "models/A2C"
logdir = "logs/A2C"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)
    
if not os.path.exists(logdir):
    os.makedirs(logdir)
    
env = gym.make("ALE/MsPacman-v5")

env.reset()

model = A2C('MlpPolicy', env, verbose = 1, tensorboard_log = logdir)
TIMESTEPS = 10000

for i in range(1, 100):
    model.learn(total_timesteps = TIMESTEPS, reset_num_timesteps = False, tb_log_name = "A2C")
    model.save(f"{models_dir}/{TIMESTEPS*i}")
# Out:
# pygame 2.1.0 (SDL 2.0.16, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to logs/A2C\A2C_0
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 442       |
# |    ep_rew_mean        | 230       |
# | time/                 |           |
# |    fps                | 20        |
# |    iterations         | 100       |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -1.97     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -0.00149  |
# |    value_loss         | 6.17e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 468      |
# |    ep_rew_mean        | 200      |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 200      |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.75    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 4.63e-06 |
# |    value_loss         | 4.96e-12 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 468       |
# |    ep_rew_mean        | 200       |
# | time/                 |           |
# |    fps                | 13        |
# |    iterations         | 300       |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -1.68     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -0.00328  |
# |    value_loss         | 7.85e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 560      |
# |    ep_rew_mean        | 220      |
# | time/                 |          |
# |    fps                | 15       |
# |    iterations         | 400      |
# |    time_elapsed       | 132      |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.79    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.0331  |
# |    value_loss         | 0.000462 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 572      |
# |    ep_rew_mean        | 242      |
# | time/                 |          |
# |    fps                | 15       |
# |    iterations         | 500      |
# |    time_elapsed       | 163      |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.737   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.0354  |
# |    value_loss         | 0.00124  |
# ------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23308\1559247730.py in <module>
#      21
#      22 for i in range(1, 30):
# ---> 23     model.learn(total_timesteps = TIMESTEPS, reset_num_timesteps = False, tb_log_name = "A2C")
#      24     model.save(f"{models_dir}/{TIMESTEPS*i}")
#
# ~\anaconda3\lib\site-packages\stable_baselines3\a2c\a2c.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     201     ) -> A2CSelf:
#     202
# --> 203         return super().learn(
#     204             total_timesteps=total_timesteps,
#     205             callback=callback,
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     260         while self.num_timesteps < total_timesteps:
#     261
# --> 262             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     263
#     264             if continue_training is False:
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     170                 # Convert to pytorch tensor or to TensorDict
#     171                 obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 172                 actions, values, log_probs = self.policy(obs_tensor)
#     173             actions = actions.cpu().numpy()
#     174
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\policies.py in forward(self, obs, deterministic)
#     585         # Preprocess the observation if needed
#     586         features = self.extract_features(obs)
# --> 587         latent_pi, latent_vf = self.mlp_extractor(features)
#     588         # Evaluate the values for the given observations
#     589         values = self.value_net(latent_vf)
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\torch_layers.py in forward(self, features)
#     228         """
#     229         shared_latent = self.shared_net(features)
# --> 230         return self.policy_net(shared_latent), self.value_net(shared_latent)
#     231
#     232     def forward_actor(self, features: th.Tensor) -> th.Tensor:
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     202     def forward(self, input):
#     203         for module in self:
# --> 204             input = module(input)
#     205         return input
#     206
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:
